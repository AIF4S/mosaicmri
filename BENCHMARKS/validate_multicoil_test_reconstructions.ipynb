# %% [markdown]
# # Validate Reconstructions: Multicoil Test
#
# Use this notebook to validate a candidate multicoil test reconstructions folder against the reference folder.
#
# Checks performed:
# - file names and folder structure must match 100%
# - candidate file keys must be exactly `ismrmrd_header` and `reconstruction_rss`
# - `reconstruction_rss` shape must match the reference for every file
# - candidate total size must be <= 8.0 GiB
#
# This notebook only validates and reports. It does not write output files.

# %%
from pathlib import Path\nfrom validate_reconstructions_core import run_validation_report\n

# %%
# Configure\nREFERENCE_ROOT = Path("MosaicMRI/multicoil_test")\nMY_ROOT = Path("MosaicMRI/multicoil_test_reconstructions")\nMAX_FOLDER_SIZE_GIB = 8.0\n
print("REFERENCE_ROOT:", REFERENCE_ROOT)\nprint("MY_ROOT:", MY_ROOT)\nprint("MAX_FOLDER_SIZE_GIB:", MAX_FOLDER_SIZE_GIB)\n

# %%
READY_TO_PACKAGE, _ = run_validation_report(\n    reference_root=REFERENCE_ROOT,\n    my_root=MY_ROOT,\n    max_folder_size_gib=MAX_FOLDER_SIZE_GIB,\n)\n
